# %%
import random
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Transportation SA

# %%
# Define the number of suppliers and customers
I = 10
J = 15

# Generate random values for ai and bj within a range
ai_values = np.random.randint(100, 1000, size=I)
bj_values = np.random.randint(50, 500, size=J)

# Define the objective function to minimize cost
def objective_function(solution):
    # Define your cost function here using the solution matrix
    # Calculate the total cost
    total_cost = np.sum(solution)  # Example: Total cost is the sum of all elements in the solution matrix
    return total_cost

# Function to generate a random initial solution matrix
def generate_initial_solution():
    # Generate an initial random solution matrix
    # Initialize a matrix with zeros of size (I, J)
    initial_solution = np.zeros((I, J))
    # Randomly assign values in the matrix respecting ai and bj constraints
    # Implement your logic to assign values based on constraints (ai_values and bj_values)
    # Example: Randomly fill the matrix respecting constraints
    for i in range(I):
        for j in range(J):
            initial_solution[i][j] = random.randint(0, min(ai_values[i], bj_values[j]))
    return initial_solution

# Simulated Annealing parameters
T = 1000  # Initial temperature
alpha = 0.9  # Cooling rate
max_iterations = 100  # Maximum iterations

# Simulated Annealing algorithm
def simulated_annealing():
    global T
    current_solution = generate_initial_solution()
    best_solution = current_solution.copy()
    best_cost = objective_function(best_solution)
    iteration_combinations = []
    def perturb_solution(solution):
        # Implement logic to perturb the current solution
        # Example: Randomly modify a value in the solution matrix
        new_solution = solution.copy()
        i = random.randint(0, I - 1)  # Select a random supplier index
        j = random.randint(0, J - 1)  # Select a random customer index
        new_solution[i][j] = random.randint(0, min(ai_values[i], bj_values[j]))  # Modify the selected value
        return new_solution

    for iteration in range(max_iterations):
        T *= alpha  # Cooling schedule

        # Generate a new solution by making a small change to the current solution
        # Implement your logic to generate a neighboring solution
        new_solution = perturb_solution(current_solution)

        # Calculate the cost of the new solution
        new_cost = objective_function(new_solution)

        # Calculate the change in cost
        delta_cost = new_cost - best_cost

        # Check if the new solution is better or if it's accepted probabilistically
        if delta_cost < 0 or random.random() < np.exp(-delta_cost / T):
            current_solution = new_solution.copy()
            if new_cost < best_cost:
                best_solution = new_solution.copy()
                best_cost = new_cost

        # Store iteration and best cost for graphing
        iteration_combinations.append((iteration, best_cost))

    return iteration_combinations, best_solution

# Execute simulated annealing algorithm
iteration_combinations, best_solution = simulated_annealing()

# Print the iteration combinations and the best solution found
print("Iteration combinations:")
for iteration, cost in iteration_combinations:
    print(f"Iteration: {iteration}, Best Cost: {cost}")

print("\nBest Solution:")
print(best_solution)
print("Best Cost:", objective_function(best_solution))

# Plot the graph of iteration vs. best cost
iterations, costs = zip(*iteration_combinations)
plt.figure(figsize=(8, 6))
plt.plot(iterations, costs)
plt.xlabel('Iterations')
plt.ylabel('Best Cost')
plt.title('Simulated Annealing: Iteration vs. Best Cost')
#plt.yscale('log')  # Setting logarithmic scale for the y-axis
plt.grid(True)
plt.show()
# Out:
# Iteration combinations:
# Iteration: 0, Best Cost: 22102.0
# Iteration: 1, Best Cost: 22064.0
# Iteration: 2, Best Cost: 21990.0
# Iteration: 3, Best Cost: 21990.0
# Iteration: 4, Best Cost: 21990.0
# Iteration: 5, Best Cost: 21918.0
# Iteration: 6, Best Cost: 21753.0
# Iteration: 7, Best Cost: 21718.0
# Iteration: 8, Best Cost: 21650.0
# Iteration: 9, Best Cost: 21583.0
# Iteration: 10, Best Cost: 21583.0
# Iteration: 11, Best Cost: 21583.0
# Iteration: 12, Best Cost: 21583.0
# Iteration: 13, Best Cost: 21583.0
# Iteration: 14, Best Cost: 21434.0
# Iteration: 15, Best Cost: 21434.0
# Iteration: 16, Best Cost: 21329.0
# Iteration: 17, Best Cost: 21164.0
# Iteration: 18, Best Cost: 21164.0
# Iteration: 19, Best Cost: 21164.0
# Iteration: 20, Best Cost: 21142.0
# Iteration: 21, Best Cost: 21142.0
# Iteration: 22, Best Cost: 21125.0
# Iteration: 23, Best Cost: 21099.0
# Iteration: 24, Best Cost: 20907.0
# Iteration: 25, Best Cost: 20875.0
# Iteration: 26, Best Cost: 20805.0
# Iteration: 27, Best Cost: 20685.0
# Iteration: 28, Best Cost: 20540.0
# Iteration: 29, Best Cost: 20529.0
# Iteration: 30, Best Cost: 20528.0
# Iteration: 31, Best Cost: 20528.0
# Iteration: 32, Best Cost: 20502.0
# Iteration: 33, Best Cost: 20502.0
# Iteration: 34, Best Cost: 20502.0
# Iteration: 35, Best Cost: 20502.0
# Iteration: 36, Best Cost: 20502.0
# Iteration: 37, Best Cost: 20497.0
# Iteration: 38, Best Cost: 20451.0
# Iteration: 39, Best Cost: 20387.0
# Iteration: 40, Best Cost: 20387.0
# Iteration: 41, Best Cost: 20387.0
# Iteration: 42, Best Cost: 20385.0
# Iteration: 43, Best Cost: 20292.0
# Iteration: 44, Best Cost: 20292.0
# Iteration: 45, Best Cost: 20292.0
# Iteration: 46, Best Cost: 20273.0
# Iteration: 47, Best Cost: 20273.0
# Iteration: 48, Best Cost: 20273.0
# Iteration: 49, Best Cost: 20273.0
# Iteration: 50, Best Cost: 20273.0
# Iteration: 51, Best Cost: 20270.0
# Iteration: 52, Best Cost: 20270.0
# Iteration: 53, Best Cost: 20270.0
# Iteration: 54, Best Cost: 20270.0
# Iteration: 55, Best Cost: 20260.0
# Iteration: 56, Best Cost: 20208.0
# Iteration: 57, Best Cost: 20208.0
# Iteration: 58, Best Cost: 20009.0
# Iteration: 59, Best Cost: 20009.0
# Iteration: 60, Best Cost: 19940.0
# Iteration: 61, Best Cost: 19931.0
# Iteration: 62, Best Cost: 19931.0
# Iteration: 63, Best Cost: 19931.0
# Iteration: 64, Best Cost: 19908.0
# Iteration: 65, Best Cost: 19908.0
# Iteration: 66, Best Cost: 19908.0
# Iteration: 67, Best Cost: 19908.0
# Iteration: 68, Best Cost: 19479.0
# Iteration: 69, Best Cost: 19383.0
# Iteration: 70, Best Cost: 19383.0
# Iteration: 71, Best Cost: 19383.0
# Iteration: 72, Best Cost: 19383.0
# Iteration: 73, Best Cost: 19383.0
# Iteration: 74, Best Cost: 19343.0
# Iteration: 75, Best Cost: 19343.0
# Iteration: 76, Best Cost: 19343.0
# Iteration: 77, Best Cost: 19314.0
# Iteration: 78, Best Cost: 19259.0
# Iteration: 79, Best Cost: 18924.0
# Iteration: 80, Best Cost: 18924.0
# Iteration: 81, Best Cost: 18924.0
# Iteration: 82, Best Cost: 18828.0
# Iteration: 83, Best Cost: 18811.0
# Iteration: 84, Best Cost: 18811.0
# Iteration: 85, Best Cost: 18811.0
# Iteration: 86, Best Cost: 18803.0
# Iteration: 87, Best Cost: 18803.0
# Iteration: 88, Best Cost: 18782.0
# Iteration: 89, Best Cost: 18782.0
# Iteration: 90, Best Cost: 18782.0
# Iteration: 91, Best Cost: 18782.0
# Iteration: 92, Best Cost: 18782.0
# Iteration: 93, Best Cost: 18782.0
# Iteration: 94, Best Cost: 18782.0
# Iteration: 95, Best Cost: 18782.0
# Iteration: 96, Best Cost: 18724.0
# Iteration: 97, Best Cost: 18724.0
# Iteration: 98, Best Cost: 18724.0
# Iteration: 99, Best Cost: 18724.0
#
# Best Solution:
# [[165. 142. 357.   3. 134.  30.  46. 285.  48. 108. 242.  22. 273. 169.
#   300.]
#  [133.  31. 181. 233.  11. 115.  58.  86. 195.  76. 156. 100. 188.  25.
#    41.]
#  [182. 161. 201. 287.  81. 141.  26. 109.  67. 115.  21.  32. 271.  44.
#   183.]
#  [131.  16. 252.  47. 220. 476.   5.  28. 222.  12. 185.  13.  32.  12.
#   102.]
#  [106. 178. 117. 189.  64.  93.  61. 145.  79.  42.  81.  29. 149. 171.
#   231.]
#  [ 47.   9. 126.  72.  48.  48.  21. 250. 116. 171. 158.  41. 207.  10.
#    31.]
#  [183. 148.  66. 242. 111.  70.  22. 198.  16. 171. 158.   1.  39. 118.
#   276.]
#  [189. 118. 138.  91.  68. 112.   8. 126. 100.  88.  29. 124.  34.  92.
#    53.]
#  [244.  34.  92. 329. 265. 360.   3. 256. 158. 136. 164.  58. 211. 112.
#   152.]
#  [227.  16. 229.  19. 247. 473.  35. 364. 276.  35.  12.  36.  15.  62.
#   198.]]
# Best Cost: 18724.0

# %%
# Define the number of suppliers and customers
I = 15
J = 20

# Generate random values for ai and bj within a range
ai_values = np.random.randint(100, 1000, size=I)
bj_values = np.random.randint(50, 500, size=J)

# Define the objective function to minimize cost
def objective_function(solution):
    # Define your cost function here using the solution matrix
    # Calculate the total cost
    total_cost = np.sum(solution)  # Example: Total cost is the sum of all elements in the solution matrix
    return total_cost

# Function to generate a random initial solution matrix
def generate_initial_solution():
    # Generate an initial random solution matrix
    # Initialize a matrix with zeros of size (I, J)
    initial_solution = np.zeros((I, J))
    # Randomly assign values in the matrix respecting ai and bj constraints
    # Implement your logic to assign values based on constraints (ai_values and bj_values)
    # Example: Randomly fill the matrix respecting constraints
    for i in range(I):
        for j in range(J):
            initial_solution[i][j] = random.randint(0, min(ai_values[i], bj_values[j]))
    return initial_solution

# Simulated Annealing parameters
T = 1000  # Initial temperature
alpha = 0.9  # Cooling rate
max_iterations = 100  # Maximum iterations

# Simulated Annealing algorithm
def simulated_annealing():
    global T
    current_solution = generate_initial_solution()
    best_solution = current_solution.copy()
    best_cost = objective_function(best_solution)
    iteration_combinations = []
    def perturb_solution(solution):
        # Implement logic to perturb the current solution
        # Example: Randomly modify a value in the solution matrix
        new_solution = solution.copy()
        i = random.randint(0, I - 1)  # Select a random supplier index
        j = random.randint(0, J - 1)  # Select a random customer index
        new_solution[i][j] = random.randint(0, min(ai_values[i], bj_values[j]))  # Modify the selected value
        return new_solution

    for iteration in range(max_iterations):
        T *= alpha  # Cooling schedule

        # Generate a new solution by making a small change to the current solution
        # Implement your logic to generate a neighboring solution
        new_solution = perturb_solution(current_solution)

        # Calculate the cost of the new solution
        new_cost = objective_function(new_solution)

        # Calculate the change in cost
        delta_cost = new_cost - best_cost

        # Check if the new solution is better or if it's accepted probabilistically
        if delta_cost < 0 or random.random() < np.exp(-delta_cost / T):
            current_solution = new_solution.copy()
            if new_cost < best_cost:
                best_solution = new_solution.copy()
                best_cost = new_cost

        # Store iteration and best cost for graphing
        iteration_combinations.append((iteration, best_cost))

    return iteration_combinations, best_solution

# Execute simulated annealing algorithm
iteration_combinations, best_solution = simulated_annealing()

# Print the iteration combinations and the best solution found
print("Iteration combinations:")
for iteration, cost in iteration_combinations:
    print(f"Iteration: {iteration}, Best Cost: {cost}")

print("\nBest Solution:")
print(best_solution)
print("Best Cost:", objective_function(best_solution))

# Plot the graph of iteration vs. best cost
iterations, costs = zip(*iteration_combinations)
plt.figure(figsize=(8, 6))
plt.plot(iterations, costs)
plt.xlabel('Iterations')
plt.ylabel('Best Cost')
plt.title('Simulated Annealing: Iteration vs. Best Cost')
#plt.yscale('log')  # Setting logarithmic scale for the y-axis
plt.grid(True)
plt.show()
# Out:
# Iteration combinations:
# Iteration: 0, Best Cost: 32710.0
# Iteration: 1, Best Cost: 32627.0
# Iteration: 2, Best Cost: 32627.0
# Iteration: 3, Best Cost: 32393.0
# Iteration: 4, Best Cost: 32393.0
# Iteration: 5, Best Cost: 32168.0
# Iteration: 6, Best Cost: 32161.0
# Iteration: 7, Best Cost: 32161.0
# Iteration: 8, Best Cost: 32161.0
# Iteration: 9, Best Cost: 32161.0
# Iteration: 10, Best Cost: 32161.0
# Iteration: 11, Best Cost: 32135.0
# Iteration: 12, Best Cost: 32135.0
# Iteration: 13, Best Cost: 32000.0
# Iteration: 14, Best Cost: 32000.0
# Iteration: 15, Best Cost: 32000.0
# Iteration: 16, Best Cost: 31952.0
# Iteration: 17, Best Cost: 31952.0
# Iteration: 18, Best Cost: 31952.0
# Iteration: 19, Best Cost: 31873.0
# Iteration: 20, Best Cost: 31873.0
# Iteration: 21, Best Cost: 31873.0
# Iteration: 22, Best Cost: 31873.0
# Iteration: 23, Best Cost: 31860.0
# Iteration: 24, Best Cost: 31860.0
# Iteration: 25, Best Cost: 31749.0
# Iteration: 26, Best Cost: 31749.0
# Iteration: 27, Best Cost: 31722.0
# Iteration: 28, Best Cost: 31682.0
# Iteration: 29, Best Cost: 31682.0
# Iteration: 30, Best Cost: 31682.0
# Iteration: 31, Best Cost: 31666.0
# Iteration: 32, Best Cost: 31666.0
# Iteration: 33, Best Cost: 31644.0
# Iteration: 34, Best Cost: 31579.0
# Iteration: 35, Best Cost: 31570.0
# Iteration: 36, Best Cost: 31570.0
# Iteration: 37, Best Cost: 31488.0
# Iteration: 38, Best Cost: 31487.0
# Iteration: 39, Best Cost: 31487.0
# Iteration: 40, Best Cost: 31449.0
# Iteration: 41, Best Cost: 31449.0
# Iteration: 42, Best Cost: 31272.0
# Iteration: 43, Best Cost: 31272.0
# Iteration: 44, Best Cost: 31225.0
# Iteration: 45, Best Cost: 31175.0
# Iteration: 46, Best Cost: 31139.0
# Iteration: 47, Best Cost: 31139.0
# Iteration: 48, Best Cost: 31139.0
# Iteration: 49, Best Cost: 31139.0
# Iteration: 50, Best Cost: 31128.0
# Iteration: 51, Best Cost: 31014.0
# Iteration: 52, Best Cost: 30934.0
# Iteration: 53, Best Cost: 30934.0
# Iteration: 54, Best Cost: 30906.0
# Iteration: 55, Best Cost: 30745.0
# Iteration: 56, Best Cost: 30698.0
# Iteration: 57, Best Cost: 30611.0
# Iteration: 58, Best Cost: 30611.0
# Iteration: 59, Best Cost: 30611.0
# Iteration: 60, Best Cost: 30611.0
# Iteration: 61, Best Cost: 30611.0
# Iteration: 62, Best Cost: 30214.0
# Iteration: 63, Best Cost: 30195.0
# Iteration: 64, Best Cost: 30195.0
# Iteration: 65, Best Cost: 30193.0
# Iteration: 66, Best Cost: 30193.0
# Iteration: 67, Best Cost: 30185.0
# Iteration: 68, Best Cost: 30185.0
# Iteration: 69, Best Cost: 30074.0
# Iteration: 70, Best Cost: 30074.0
# Iteration: 71, Best Cost: 30074.0
# Iteration: 72, Best Cost: 30074.0
# Iteration: 73, Best Cost: 30074.0
# Iteration: 74, Best Cost: 30035.0
# Iteration: 75, Best Cost: 29801.0
# Iteration: 76, Best Cost: 29801.0
# Iteration: 77, Best Cost: 29560.0
# Iteration: 78, Best Cost: 29560.0
# Iteration: 79, Best Cost: 29560.0
# Iteration: 80, Best Cost: 29521.0
# Iteration: 81, Best Cost: 29521.0
# Iteration: 82, Best Cost: 29489.0
# Iteration: 83, Best Cost: 29419.0
# Iteration: 84, Best Cost: 29237.0
# Iteration: 85, Best Cost: 29237.0
# Iteration: 86, Best Cost: 29237.0
# Iteration: 87, Best Cost: 29216.0
# Iteration: 88, Best Cost: 29139.0
# Iteration: 89, Best Cost: 29124.0
# Iteration: 90, Best Cost: 29124.0
# Iteration: 91, Best Cost: 29123.0
# Iteration: 92, Best Cost: 29123.0
# Iteration: 93, Best Cost: 29050.0
# Iteration: 94, Best Cost: 29050.0
# Iteration: 95, Best Cost: 29050.0
# Iteration: 96, Best Cost: 29024.0
# Iteration: 97, Best Cost: 29024.0
# Iteration: 98, Best Cost: 29014.0
# Iteration: 99, Best Cost: 29014.0
#
# Best Solution:
# [[118. 189. 105. 206.  32.  34. 144.  66.  94.  47. 136. 223.  15.  14.
#    61.  57.  37.  83. 147.  14.]
#  [ 38. 239. 152. 227.  51.   4.  77.  82. 135.  16.  95. 226.  27.  33.
#   164. 138.   4.  32. 123. 333.]
#  [ 63.  40. 107.  30.  36.  23.  48.  37.  11.  36.  96.  10.  98.  88.
#    45.  59. 115.  17.  45. 106.]
#  [322. 259. 148. 213.  15.   7. 229.  26.  70.  22. 111.  32.  35.  24.
#    22.  41. 107.  54. 195. 217.]
#  [ 98. 176. 126. 186.   3.  32. 176.  68. 109. 119.  29.  49.  31.   2.
#    97. 148.  17. 114. 116.  71.]
#  [216.   5.  90. 341.   6.   0.  34.  15. 271.  47.  89.  32. 108.  78.
#   100.  38. 119. 210. 170. 396.]
#  [208.  65. 167. 131.  30.  20. 172.  32. 231.  98.  94. 290.  78.  77.
#   172. 123.  16. 167.  21.  53.]
#  [421. 146.  45. 105.  35.  28.   4.  27. 146. 107.  26. 213.  73.  60.
#    74.  29. 109.  74.  39. 275.]
#  [ 33.   0. 152.  32.  45.  23. 119.   9.  65. 113.  71. 188. 112.  18.
#   126.  28.  39.  81.  55.  29.]
#  [ 22.  11.  15. 218.  21.  37. 109.  54. 145.  64. 118.  91.  65.  63.
#    35. 161.  91. 171. 127.  81.]
#  [226. 301.   9.   7.  24.   3. 169.   9. 180.  74.  72. 315.   0.   1.
#   164.  93.  47. 151.  39.  40.]
#  [393. 231. 230. 285.   0.  21.  20.  10.  40.  23.  93. 287.  68.  34.
#   120.   5.   4. 209.  35. 183.]
#  [231. 239. 106.  57.  36.  12.  54.  19. 118.  92.   3. 340.   1.  14.
#    84. 183.  43. 134. 145.  66.]
#  [ 42. 321. 142. 278.  14.   5. 228.  51. 128.  88.  11. 440.  66.  67.
#     2. 162.   3. 165.  33. 254.]
#  [143.  34.  83.  74.  55.  20.  45.  14. 267.  59.  15. 251.  34.  10.
#   142.  56.  14. 158.  39.  82.]]
# Best Cost: 29014.0

# %% [markdown]
# # Genetic Algorithm Transportation

# %%
# Define the number of suppliers and customers
I = 10
J = 15

# Generate random values for ai and bj within a range
ai_values = np.random.randint(100, 1000, size=I)
bj_values = np.random.randint(50, 500, size=J)

# Define the objective function to minimize cost
def objective_function(solution):
    # Calculate the total cost of the solution matrix
    total_cost = np.sum(solution)  # Example: Total cost is the sum of all elements in the solution matrix
    return total_cost

# Generate initial population
def generate_population(population_size):
    population = []
    for _ in range(population_size):
        # Generate a random solution respecting constraints and add to the population
        solution = np.random.randint(0, np.minimum(ai_values[:, np.newaxis], bj_values), size=(I, J))
        population.append(solution)
    return population

# Genetic Algorithm parameters
max_iterations = 100
Pr = 60  # Probability of selection for reproduction
Pc = 40  # Probability of crossover
Pm = 10  # Probability of mutation
population_size = 100

# Implement GA operators: selection, crossover, mutation, replacement

# Run Genetic Algorithm
def genetic_algorithm():
    population = generate_population(population_size)
    best_solution = None
    best_cost = float('inf')
    iteration_combinations = []

    for iteration in range(max_iterations):
        
        # Example code: Random selection of individuals for reproduction (can be replaced with more sophisticated methods)
        selected_parents = random.choices(population, k=int(Pr * population_size))

        # Example code: Single-point crossover (can be replaced with other crossover methods)
        for i in range(0, len(selected_parents), 2):
            crossover_point = random.randint(1, I - 1)
            parent1, parent2 = selected_parents[i], selected_parents[i + 1]
            child1 = np.vstack((parent1[:crossover_point], parent2[crossover_point:]))
            child2 = np.vstack((parent2[:crossover_point], parent1[crossover_point:]))
            population.extend([child1, child2])

        # Example code: Random mutation (can be replaced with more sophisticated methods)
        for i in range(int(Pm * population_size)):
            idx = random.randint(0, population_size - 1)
            mutation_point = (random.randint(0, I - 1), random.randint(0, J - 1))
            population[idx][mutation_point] = random.randint(0, min(ai_values[mutation_point[0]], bj_values[mutation_point[1]]))

        # Example code: Elitism - select best solutions for the next iteration
        costs = [objective_function(sol) for sol in population]
        sorted_indices = np.argsort(costs)
        population = [population[i] for i in sorted_indices[:population_size]]

        # Store iteration and best cost for graphing
        costs = [objective_function(sol) for sol in population]
        idx = np.argmin(costs)
        current_best_solution = population[idx]
        current_best_cost = costs[idx]
        if current_best_cost < best_cost:
            best_solution = current_best_solution
            best_cost = current_best_cost
        iteration_combinations.append((iteration, best_cost))

    return iteration_combinations, best_solution, best_cost

# Execute genetic algorithm
iteration_combinations, best_solution, best_cost = genetic_algorithm()

# Print the best combination and the best objective function
print("Best Combination:")
print(best_solution)
print("Best Objective Function (Cost):", best_cost)

# Plot the graph of iteration vs. best cost
iterations, costs = zip(*iteration_combinations)
plt.plot(iterations, costs)
plt.xlabel('Iterations')
plt.ylabel('Best Cost')
plt.title('Genetic Algorithm: Iteration vs. Best Cost')
plt.show()
# Out:
# Best Combination:
# [[  6  57 110  59  34  16   9   2   5  89  58  50  10  42   2]
#  [122   3  10  15   7   3   6  40 103  50  16  19 101  58  41]
#  [ 19 102  27  55  51  37  24  23  21  34   7   3  32  31   8]
#  [ 53  28  52   7   3 103   0   7  58   5  25  40  47  39  32]
#  [  2  56  28  11  41  25   0  50  31  27  18  26   0   9   4]
#  [ 83  76  11   5  16  63  24  32  11  14   6  53 118  44  15]
#  [ 26   0  23  28  44  11  16  18  33  28  21  18  32  41  35]
#  [ 12  29  17  42  33  85  64  33  21   7  26  49  61   0 130]
#  [ 36  30   5  19  53  95  49   3  10  25  32  29   8  42  11]
#  [  9   6  17   2  13  33  81   5  72  50  23  26  82  18  19]]
# Best Objective Function (Cost): 4287

# %%
# Define the number of suppliers and customers
I = 15
J = 20

# Generate random values for ai and bj within a range
ai_values = np.random.randint(100, 1000, size=I)
bj_values = np.random.randint(50, 500, size=J)

# Define the objective function to minimize cost
def objective_function(solution):
    # Calculate the total cost of the solution matrix
    total_cost = np.sum(solution)  # Example: Total cost is the sum of all elements in the solution matrix
    return total_cost

# Generate initial population
def generate_population(population_size):
    population = []
    for _ in range(population_size):
        # Generate a random solution respecting constraints and add to the population
        solution = np.random.randint(0, np.minimum(ai_values[:, np.newaxis], bj_values), size=(I, J))
        population.append(solution)
    return population

# Genetic Algorithm parameters
max_iterations = 100
Pr = 60  # Probability of selection for reproduction
Pc = 40  # Probability of crossover
Pm = 10  # Probability of mutation
population_size = 100

# Implement GA operators: selection, crossover, mutation, replacement

# Run Genetic Algorithm
def genetic_algorithm():
    population = generate_population(population_size)
    best_solution = None
    best_cost = float('inf')
    iteration_combinations = []

    for iteration in range(max_iterations):
        # Implement GA operators: selection, crossover, mutation, replacement
        
        # Example code: Random selection of individuals for reproduction (can be replaced with more sophisticated methods)
        selected_parents = random.choices(population, k=int(Pr * population_size))

        # Example code: Single-point crossover (can be replaced with other crossover methods)
        for i in range(0, len(selected_parents), 2):
            crossover_point = random.randint(1, I - 1)
            parent1, parent2 = selected_parents[i], selected_parents[i + 1]
            child1 = np.vstack((parent1[:crossover_point], parent2[crossover_point:]))
            child2 = np.vstack((parent2[:crossover_point], parent1[crossover_point:]))
            population.extend([child1, child2])

        # Example code: Random mutation (can be replaced with more sophisticated methods)
        for i in range(int(Pm * population_size)):
            idx = random.randint(0, population_size - 1)
            mutation_point = (random.randint(0, I - 1), random.randint(0, J - 1))
            population[idx][mutation_point] = random.randint(0, min(ai_values[mutation_point[0]], bj_values[mutation_point[1]]))

        # Example code: Elitism - select best solutions for the next iteration
        costs = [objective_function(sol) for sol in population]
        sorted_indices = np.argsort(costs)
        population = [population[i] for i in sorted_indices[:population_size]]

        # Store iteration and best cost for graphing
        costs = [objective_function(sol) for sol in population]
        idx = np.argmin(costs)
        current_best_solution = population[idx]
        current_best_cost = costs[idx]
        if current_best_cost < best_cost:
            best_solution = current_best_solution
            best_cost = current_best_cost
        iteration_combinations.append((iteration, best_cost))

    return iteration_combinations, best_solution, best_cost

# Execute genetic algorithm
iteration_combinations, best_solution, best_cost = genetic_algorithm()

# Print the best combination and the best objective function
print("Best Combination:")
print(best_solution)
print("Best Objective Function (Cost):", best_cost)

# Plot the graph of iteration vs. best cost
iterations, costs = zip(*iteration_combinations)
plt.plot(iterations, costs)
plt.xlabel('Iterations')
plt.ylabel('Best Cost')
plt.title('Genetic Algorithm: Iteration vs. Best Cost')
plt.show()
# Out:
# Best Combination:
# [[125  96   4  42  36  37 110  51  22  23  73  21  74  53  19  63   8   4
#    63   2]
#  [  3  10  19 417 148  89 132 107  33  42 148  93  48  27  24  62  85  38
#    19   4]
#  [ 50  37  50 149  11  96  61  43   6  75  99   1  79   4 105   9  93  49
#    21 168]
#  [100  60  29 173  62 394  57  74  47  52  18  12  16   7  64   8 111  21
#    38  18]
#  [ 21  18  69  39  41  25  60 110  52  23  34  97  75  70 109  14  86  29
#     3  11]
#  [ 21  48 115  13  68  53  36  26  52  49   0  21  92  40  54 126   6  18
#    42  72]
#  [ 34 141  35 241  24  61   1  18  35  17  37  96  14  50  91  38  79  49
#    74  55]
#  [ 13   1   7  41   1  30   1  54  28  43  87  52   5  27  46   1   8  43
#   104  33]
#  [ 69   8 169  48  86  42  21   9  22  53  15   7  83  39  33  31   9  64
#    30 235]
#  [  6  42   0 169  49  57  43 104   9   7  80   7  26  35  42  23 123  55
#    43  33]
#  [ 37  68  24 193  13 103  59  14  43  15  19  20  11  20  19  61  25  30
#     0  73]
#  [122   8 204  31  18  47  47   9 111   3  36  30  95 129  32  56  60  80
#    43  38]
#  [ 13  49 125  68  70 103  75  13  19  19 212   7  28   3  57   0  97  30
#     7   2]
#  [ 66 156  33  29  49  21  31  33  39   2  30   3 130  36  64  37  19  41
#    29  37]
#  [  0  59   8  62  29  17  65  38  81  16  77 118  42  18  13   6  11   4
#    31  41]]
# Best Objective Function (Cost): 14639

# %% [markdown]
# # Simulated Annealing for Scheduling

# %%
#10 Jobs
#Function to calculate the objective value
def objective_function(sequence, processing_times, due_dates, earliness_penalty, tardiness_penalty):
    total_time = 0
    total_earliness_penalty = 0
    total_tardiness_penalty = 0

    for i, job in enumerate(sequence):
        completion_time = max(total_time, due_dates[job])
        earliness = max(0, due_dates[job] - total_time)
        tardiness = max(0, total_time - due_dates[job])

        total_earliness_penalty += earliness * earliness_penalty
        total_tardiness_penalty += tardiness * tardiness_penalty

        total_time = completion_time + processing_times[job]

    return total_time + total_earliness_penalty + total_tardiness_penalty

# Simulated Annealing Algorithm
def simulated_annealing(processing_times, due_dates, earliness_penalty, tardiness_penalty, initial_temperature, cooling_rate, iterations):
    n_jobs = len(processing_times)
    current_sequence = np.arange(n_jobs)
    np.random.shuffle(current_sequence)
    current_objective = objective_function(current_sequence, processing_times, due_dates, earliness_penalty, tardiness_penalty)

    best_sequence = np.copy(current_sequence)
    best_objective = current_objective

    temperatures = [initial_temperature * (cooling_rate ** i) for i in range(iterations)]

    cost_evolution = []  # List to store the cost at each iteration

    for iteration in range(iterations):
        temperature = temperatures[iteration]

        # Generate a neighboring solution by swapping two jobs
        neighbor_sequence = np.copy(current_sequence)
        idx1, idx2 = np.random.choice(n_jobs, size=2, replace=False)
        neighbor_sequence[idx1], neighbor_sequence[idx2] = neighbor_sequence[idx2], neighbor_sequence[idx1]

        neighbor_objective = objective_function(neighbor_sequence, processing_times, due_dates, earliness_penalty, tardiness_penalty)

        # Accept the neighbor if it is better or with a certain probability if it is worse
        if neighbor_objective < current_objective or np.random.rand() < np.exp((current_objective - neighbor_objective) / temperature):
            current_sequence = np.copy(neighbor_sequence)
            current_objective = neighbor_objective

        # Update the best solution
        if current_objective < best_objective:
            best_sequence = np.copy(current_sequence)
            best_objective = current_objective

        cost_evolution.append(best_objective)

    # Plot results
    plt.plot(cost_evolution)
    plt.title('Scheduling with SA')
    plt.xlabel('Iteration')
    plt.ylabel('Production Time')
    plt.grid(True)
    plt.show()

    return best_sequence, best_objective

# Set random seed for reproducibility
np.random.seed(42)

# Parameters
n_jobs = 10
processing_times = np.random.randint(1, 10, size=n_jobs)
due_dates = np.random.randint(10, 20, size=n_jobs)
earliness_penalty = 1
tardiness_penalty = 2
initial_temperature = 1000
cooling_rate = 0.9
iterations = 100

# Run Simulated Annealing
best_sequence, best_objective = simulated_annealing(processing_times, due_dates, earliness_penalty, tardiness_penalty, initial_temperature, cooling_rate, iterations)

# Print results
print("Best Sequence:", best_sequence)
print("Best Objective Value:", best_objective)
# Out:
# Best Sequence: [5 9 1 3 8 0 6 4 7 2]
# Best Objective Value: 440

# %%
#15 Jobs
#Function to calculate the objective value
def objective_function(sequence, processing_times, due_dates, earliness_penalty, tardiness_penalty):
    total_time = 0
    total_earliness_penalty = 0
    total_tardiness_penalty = 0

    for i, job in enumerate(sequence):
        completion_time = max(total_time, due_dates[job])
        earliness = max(0, due_dates[job] - total_time)
        tardiness = max(0, total_time - due_dates[job])

        total_earliness_penalty += earliness * earliness_penalty
        total_tardiness_penalty += tardiness * tardiness_penalty

        total_time = completion_time + processing_times[job]

    return total_time + total_earliness_penalty + total_tardiness_penalty

# Simulated Annealing Algorithm
def simulated_annealing(processing_times, due_dates, earliness_penalty, tardiness_penalty, initial_temperature, cooling_rate, iterations):
    n_jobs = len(processing_times)
    current_sequence = np.arange(n_jobs)
    np.random.shuffle(current_sequence)
    current_objective = objective_function(current_sequence, processing_times, due_dates, earliness_penalty, tardiness_penalty)

    best_sequence = np.copy(current_sequence)
    best_objective = current_objective

    temperatures = [initial_temperature * (cooling_rate ** i) for i in range(iterations)]

    cost_evolution = []  # List to store the cost at each iteration

    for iteration in range(iterations):
        temperature = temperatures[iteration]

        # Generate a neighboring solution by swapping two jobs
        neighbor_sequence = np.copy(current_sequence)
        idx1, idx2 = np.random.choice(n_jobs, size=2, replace=False)
        neighbor_sequence[idx1], neighbor_sequence[idx2] = neighbor_sequence[idx2], neighbor_sequence[idx1]

        neighbor_objective = objective_function(neighbor_sequence, processing_times, due_dates, earliness_penalty, tardiness_penalty)

        # Accept the neighbor if it is better or with a certain probability if it is worse
        if neighbor_objective < current_objective or np.random.rand() < np.exp((current_objective - neighbor_objective) / temperature):
            current_sequence = np.copy(neighbor_sequence)
            current_objective = neighbor_objective

        # Update the best solution
        if current_objective < best_objective:
            best_sequence = np.copy(current_sequence)
            best_objective = current_objective

        cost_evolution.append(best_objective)

    # Plot results
    plt.plot(cost_evolution)
    plt.title('Scheduling with SA')
    plt.xlabel('Iteration')
    plt.ylabel('Production Time')
    plt.grid(True)
    plt.show()

    return best_sequence, best_objective

# Set random seed for reproducibility
np.random.seed(42)

# Parameters
n_jobs = 15
processing_times = np.random.randint(1, 10, size=n_jobs)
due_dates = np.random.randint(10, 20, size=n_jobs)
earliness_penalty = 1
tardiness_penalty = 2
initial_temperature = 1000
cooling_rate = 0.9
iterations = 100

# Run Simulated Annealing
best_sequence, best_objective = simulated_annealing(processing_times, due_dates, earliness_penalty, tardiness_penalty, initial_temperature, cooling_rate, iterations)

# Print results
print("Best Sequence:", best_sequence)
print("Best Objective Value:", best_objective)
# Out:
# Best Sequence: [ 0  1  9  5 12 14  8 13  4  3  7  6  2 10 11]
# Best Objective Value: 1068

# %% [markdown]
# # Scheduling with Genetic Algorithm

# %%
#10 jobs
# Function to calculate the fitness of a schedule
def calculate_fitness(schedule, processing_times, due_dates, earliness_penalty, tardiness_penalty):
    completion_times = np.cumsum(schedule[:, :15], axis=1)
    tardiness = np.maximum(0, completion_times - due_dates)
    earliness = np.maximum(0, due_dates - completion_times)
    total_tardiness_penalty = np.sum(tardiness * tardiness_penalty)
    total_earliness_penalty = np.sum(earliness * earliness_penalty)
    total_time = np.max(completion_times[:, -1])
    fitness = total_time + total_tardiness_penalty + total_earliness_penalty
    return fitness

# Genetic Algorithm Function
def genetic_algorithm(num_iterations, num_population, num_jobs, prob_reproduction, prob_crossover, prob_mutation):
    # Initialize parameters
    processing_times = np.random.randint(1, 20, size=(num_population, num_jobs))
    due_dates = np.random.randint(20, 40, size=(num_population, num_jobs))
    earliness_penalty = np.ones(num_jobs) * 2  # Constant earliness penalty for all jobs
    tardiness_penalty = np.random.randint(1, 5, size=num_jobs)

    best_schedule = None
    best_fitness = float('inf')
    all_fitness = []

    for iteration in range(num_iterations):
        # Evaluate fitness for each individual in the population
        fitness_values = np.zeros(num_population)
        for i in range(num_population):
            fitness_values[i] = calculate_fitness(
                processing_times[i:i+1, :],
                processing_times[i:i+1, :],
                due_dates[i:i+1, :],
                earliness_penalty,
                tardiness_penalty
            )

        # Select parents for reproduction using roulette wheel selection
        total_fitness = np.sum(fitness_values)
        probabilities = fitness_values / total_fitness
        selected_indices = np.random.choice(num_population, size=num_population, p=probabilities)

        # Reproduction (crossover and mutation)
        for i in range(0, num_population, 2):
            if np.random.rand() < prob_reproduction:
                # Crossover
                crossover_point = np.random.randint(1, num_jobs)
                child1 = np.concatenate([processing_times[selected_indices[i], :crossover_point],
                                         processing_times[selected_indices[i+1], crossover_point:]])
                child2 = np.concatenate([processing_times[selected_indices[i+1], :crossover_point],
                                         processing_times[selected_indices[i], crossover_point:]])

                # Mutation
                if np.random.rand() < prob_mutation:
                    mutation_point = np.random.randint(num_jobs)
                    child1[mutation_point] = np.random.randint(1, 20)
                    child2[mutation_point] = np.random.randint(1, 20)

                # Replace parents with children
                processing_times[selected_indices[i], :] = child1
                processing_times[selected_indices[i+1], :] = child2

        # Find the best schedule and update the best fitness
        current_best_index = np.argmin(fitness_values)
        current_best_schedule = processing_times[current_best_index, :]
        current_best_fitness = fitness_values[current_best_index]

        if current_best_fitness < best_fitness:
            best_schedule = current_best_schedule
            best_fitness = current_best_fitness

        all_fitness.append(best_fitness)

    return best_schedule, best_fitness, all_fitness

# Main function
def main():
    num_iterations = 100
    num_population = 100
    num_jobs = 10
    prob_reproduction = 0.6
    prob_crossover = 0.4
    prob_mutation = 0.1

    best_schedule, best_fitness, all_fitness = genetic_algorithm(
        num_iterations, num_population, num_jobs, prob_reproduction, prob_crossover, prob_mutation
    )

    print("Best Schedule:", best_schedule)
    print("Best Fitness:", best_fitness)

    # Plot the evolution of the best fitness
    plt.plot(all_fitness,)
    plt.xlabel('Iterations')
    plt.ylabel('Best Fitness')
    plt.title('Genetic Algorithm for Job Scheduling')
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Best Schedule: [ 3 12  1  3  7  3  5  2 14 12]
# Best Fitness: 297.0

# %%
#15 jobs
# Function to calculate the fitness of a schedule
def calculate_fitness(schedule, processing_times, due_dates, earliness_penalty, tardiness_penalty):
    completion_times = np.cumsum(schedule[:, :15], axis=1)
    tardiness = np.maximum(0, completion_times - due_dates)
    earliness = np.maximum(0, due_dates - completion_times)
    total_tardiness_penalty = np.sum(tardiness * tardiness_penalty)
    total_earliness_penalty = np.sum(earliness * earliness_penalty)
    total_time = np.max(completion_times[:, -1])
    fitness = total_time + total_tardiness_penalty + total_earliness_penalty
    return fitness

# Genetic Algorithm Function
def genetic_algorithm(num_iterations, num_population, num_jobs, prob_reproduction, prob_crossover, prob_mutation):
    # Initialize parameters
    processing_times = np.random.randint(1, 20, size=(num_population, num_jobs))
    due_dates = np.random.randint(20, 40, size=(num_population, num_jobs))
    earliness_penalty = np.ones(num_jobs) * 2  # Constant earliness penalty for all jobs
    tardiness_penalty = np.random.randint(1, 5, size=num_jobs)

    best_schedule = None
    best_fitness = float('inf')
    all_fitness = []

    for iteration in range(num_iterations):
        # Evaluate fitness for each individual in the population
        fitness_values = np.zeros(num_population)
        for i in range(num_population):
            fitness_values[i] = calculate_fitness(
                processing_times[i:i+1, :],
                processing_times[i:i+1, :],
                due_dates[i:i+1, :],
                earliness_penalty,
                tardiness_penalty
            )

        # Select parents for reproduction using roulette wheel selection
        total_fitness = np.sum(fitness_values)
        probabilities = fitness_values / total_fitness
        selected_indices = np.random.choice(num_population, size=num_population, p=probabilities)

        # Reproduction (crossover and mutation)
        for i in range(0, num_population, 2):
            if np.random.rand() < prob_reproduction:
                # Crossover
                crossover_point = np.random.randint(1, num_jobs)
                child1 = np.concatenate([processing_times[selected_indices[i], :crossover_point],
                                         processing_times[selected_indices[i+1], crossover_point:]])
                child2 = np.concatenate([processing_times[selected_indices[i+1], :crossover_point],
                                         processing_times[selected_indices[i], crossover_point:]])

                # Mutation
                if np.random.rand() < prob_mutation:
                    mutation_point = np.random.randint(num_jobs)
                    child1[mutation_point] = np.random.randint(1, 20)
                    child2[mutation_point] = np.random.randint(1, 20)

                # Replace parents with children
                processing_times[selected_indices[i], :] = child1
                processing_times[selected_indices[i+1], :] = child2

        # Find the best schedule and update the best fitness
        current_best_index = np.argmin(fitness_values)
        current_best_schedule = processing_times[current_best_index, :]
        current_best_fitness = fitness_values[current_best_index]

        if current_best_fitness < best_fitness:
            best_schedule = current_best_schedule
            best_fitness = current_best_fitness

        all_fitness.append(best_fitness)

    return best_schedule, best_fitness, all_fitness

# Main function
def main():
    num_iterations = 100
    num_population = 100
    num_jobs = 15
    prob_reproduction = 0.6
    prob_crossover = 0.4
    prob_mutation = 0.1

    best_schedule, best_fitness, all_fitness = genetic_algorithm(
        num_iterations, num_population, num_jobs, prob_reproduction, prob_crossover, prob_mutation
    )

    print("Best Schedule:", best_schedule)
    print("Best Fitness:", best_fitness)

    # Plot the evolution of the best fitness
    plt.plot(all_fitness,)
    plt.xlabel('Iterations')
    plt.ylabel('Best Fitness')
    plt.title('Genetic Algorithm for Job Scheduling')
    plt.show()

if __name__ == "__main__":
    main()
# Out:
# Best Schedule: [ 3  2 17 19  4 14  8 19 18  4  4 14  8 15 10]
# Best Fitness: 1249.0
